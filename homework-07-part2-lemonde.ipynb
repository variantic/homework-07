# %% [markdown]
# # Scraping Le Monde

# %%
from bs4 import BeautifulSoup
import requests

response = requests.get("https://www.lemonde.fr/en")
doc = BeautifulSoup(response.text)

# %%
body = doc.find("main")
len(body)
# Out:
# 11

# %%
articles = body.find_all(class_="article")
articles
len(articles)
# Out:
# 25

# %%
for article in articles:
    print("------")
    print(article.text)
# Out:
# ------
#    Iran warns of 'devastating response' to Israel attacks            TOMER NEUBERG / REUTERS  'Leave the occupied territories because they will certainly no longer be habitable in the future," and shelters will 'not guarantee security', an Iranian spokesman for the armed forces said on Sunday. Tehran also reported that the intelligence chief of Iran's Revolutionary Guards had been killed in an Israeli strike.   Israel, Iran exchange deadly strikes for third day    Subscribers only The collapse of the 'axis of resistance'
# ------
#          Mads Claus Rasmussen / via REUTERS   In Greenland, Macron criticizes Trump's annexation threats: 'That's not what allies do'
# ------
#          BORIS SEMENIAKO  Subscribers only Was the Trump phenomenon a historical accident? Reinterpreting the history of the American right
# ------
#          HECTOR PASSAT  Subscribers only France's first Slow Fashion Week champions a simple, recycled approach to fashion  Designers and vintage enthusiasts gathered in Marseille from June 7 to June 14, far from the glitz of major fashion capitals, to promote an alternative fashion model where secondhand clothing takes center stage.
# ------
#          Jae Hong / AP   Paris Saint-Germain thrash Atlético 4-0 in Club World Cup Opener  PSG largely dominated Atlético at the Rose Bowl on Sunday, in its first match since trouncing Inter Milan 5-0 to win its first Champions League title on May 31.
# ------
#          Fred Péault  Subscribers only The young professionals taking their parents' experiences to heart and changing how they work  Between exhaustion, loss of meaning and admiration, the younger generation is shaping its relationship with work after witnessing their parents' professional struggles and the profound transformation of the workplace.
# ------
#               Video investigation  Alexandre Horn,  Marceau Bretonnier and  Sinead McCausland Subscribers onlyWar in Ukraine: How FPV drones are transforming the battlefield Le Monde has compiled dozens of verified videos from the front lines to document the decisive impact of these low-cost drones.   08:05 min watch
# ------
#          Search for suspect in shooting of two Minnesota lawmakers leads to one of his vehicles in rural area
# ------
#         Subscribers only Poland delivers Trump his first electoral victory in Europe
# ------
#         Subscribers only French health authorities launch major study of pollutants' impact on population's health
# ------
#          Is it ever a good idea to... wear your sunglasses on your head?
# ------
#   Subscribers only French car maker Renault could make drones in Ukraine, signaling the automotive industry's shift into defense
# ------
#    Sarkozy stripped of Legion of Honor
# ------
#   Subscribers only At Paris protest in support of Gaza, anger and fear run high
# ------
#    Ferrari wins third consecutive 24 Hours of Le Mans
# ------
#   Subscribers only Away from Trump, world leaders make progress on key ocean issues
# ------
#   Subscribers only Kazakhstan families search for clues about the 270,000 'missing soldiers' of the World War II Soviet Army
# ------
#   Subscribers only On the Canadian side of lake Ontario, a new identity emerges in the shadow of Trump
# ------
#   Subscribers only Democratic lawmaker assassinated in Minnesota: The suspect's unusual profile
# ------
#            In Depth  Elise Vincent and  Philippe Ricard Subscribers onlyEurope's paradoxical support for Israel's attack against Iran France, the United Kingdom and Germany expressed their support on Friday for Israel's 'right to defend itself' against the nuclear threat posed by the Islamic Republic of Iran, despite deteriorating relations with Benjamin Netanyahu because of his war in Gaza and their stated preference for a diplomatic approach.  4 min read
# ------
#            Feature  Eliott Dumoulin Subscribers onlyOn the Canadian side of lake Ontario, a new identity emerges in the shadow of Trump Straddling the border between Canada and the US, Lake Ontario has long served as a model for the harmonious management of a shared space. But Donald Trump's declarations undermine that balance.  13 min read
# ------
#            News analysis  Hélène Sallon Subscribers onlyThe collapse of the 'axis of resistance' Faced with Israel, the Islamic Republic of Iran can no longer count on its allies in Lebanon, Iraq and Yemen, which have been weakened since Hamas's attack on Israel, on October 7, 2023.  3 min read
# ------
#   Editorial Israel's war in Iran: The choice of war and its risks Le Monde
# ------
#   Column SubscribeThomas Piketty: 'Opponents of the tax on the ultra-wealthy lack historical perspective'   Thomas Piketty Professor at EHESS and the Paris School of Economics
# ------
#   Column Subscribe'There is a world of difference between how the media portrays JK Rowling and her image among the public'    Michel Guerrin Columnist

# %% [markdown]
# #### Now to scrape title, subhead, article URL, whether it's premium or not, byline, article type, image URL

# %%
for article in articles:
    print("------")
    # title
    print(article.find(class_='article__title').text)
    # subhead
    try:
        print(article.find(class_='article__desc').text)
    except:
        print("No subhead")
    # url
    try:
        print(article.find('a')['href'])
    except:
        print("No url")
    # premium
    try:
        print(article.find(class_='sr-only').text)
    except:
        print("Free to read")
    # byline
    try:
        print(article.select_one('.article__byline, .article__author-name').text)
    except:
        print("No byline")
    # type
    try:
        print(article.find(class_="article__type").text)
    except:
        print("No article type")
    # image url
    try:
        print(article.find('img').get('data-src', None))
    except:
        print("No image")
# Out:
# ------
#  Iran warns of 'devastating response' to Israel attacks
# 'Leave the occupied territories because they will certainly no longer be habitable in the future," and shelters will 'not guarantee security', an Iranian spokesman for the armed forces said on Sunday. Tehran also reported that the intelligence chief of Iran's Revolutionary Guards had been killed in an Israeli strike.
# https://www.lemonde.fr/en/international/article/2025/06/15/iran-warns-of-devastating-response-to-israel-attacks_6742369_4.html
# Subscribers only
# No byline
# No article type
# None
# ------
# In Greenland, Macron criticizes Trump's annexation threats: 'That's not what allies do'
# No subhead
# https://www.lemonde.fr/en/international/article/2025/06/15/in-greenland-macron-criticizes-trump-s-annexation-threats-that-s-not-what-allies-do_6742364_4.html
# Free to read
# No byline
# No article type
# https://img.lemde.fr/2025/06/15/0/0/4320/2880/398/265/75/0/899bed8_ftp-import-images-1-btqov54uiqar-2025-06-15t125318z-697523675-rc203fadvtlx-rtrmadp-3-greenland-france.JPG
# ------
# Was the Trump phenomenon a historical accident? Reinterpreting the history of the American right
# No subhead
# https://www.lemonde.fr/en/international/article/2025/06/15/was-the-trump-phenomenon-a-historical-accident-reinterpreting-the-history-of-the-american-right_6742368_4.html
# Subscribers only
# No byline
# No article type
# https://img.lemde.fr/2025/05/29/611/0/3250/2166/398/265/75/0/8b58107_sirius-fs-upload-1-reczjovqtnvn-1748532786085-droiteamericaine.jpg
# ------
# France's first Slow Fashion Week champions a simple, recycled approach to fashion
# Designers and vintage enthusiasts gathered in Marseille from June 7 to June 14, far from the glitz of major fashion capitals, to promote an alternative fashion model where secondhand clothing takes center stage.
# https://www.lemonde.fr/en/environment/article/2025/06/16/france-s-first-slow-fashion-week-champions-a-simple-recycled-approach-to-fashion_6742376_114.html
# Subscribers only
# No byline
# No article type
# https://img.lemde.fr/2025/06/14/85/0/2048/1365/398/265/75/0/a84e940_upload-1-w16z1d7z2uzn-hector-passat-maisoncleo00048.jpg
# ------
# Paris Saint-Germain thrash Atlético 4-0 in Club World Cup Opener
# Subscribers only
#  Eliott Dumoulin
# Feature
# https://img.lemde.fr/2025/05/28/250/0/1500/1000/664/442/75/0/12e67b9_ftp-import-images-1-gsveaohjspcy-383807-3424387.jpg
# ------
# The collapse of the 'axis of resistance'
# Faced with Israel, the Islamic Republic of Iran can no longer count on its allies in Lebanon, Iraq and Yemen, which have been weakened since Hamas's attack on Israel, on October 7, 2023.
# https://www.lemonde.fr/en/international/article/2025/06/14/israel-s-attack-on-iran-the-collapse-of-the-pro-tehran-axis-of-resistance_6742345_4.html
# Subscribers only
#  Hélène Sallon
# News analysis
# https://img.lemde.fr/2025/06/13/0/0/4804/3203/664/442/75/0/611cdfe_upload-1-hwlrka92rb0i-525197.jpg
# ------
# Israel's war in Iran: The choice of war and its risks
# No subhead
# https://www.lemonde.fr/en/opinion/article/2025/06/14/israel-s-war-in-iran-the-choice-of-war-and-its-risks_6742338_23.html
# Free to read
# Le Monde
# Editorial
# No image
# ------
# Thomas Piketty: 'Opponents of the tax on the ultra-wealthy lack historical perspective'
# No subhead
# https://www.lemonde.fr/en/opinion/article/2025/06/14/thomas-piketty-opponents-of-the-tax-on-the-ultra-wealthy-lack-historical-perspective_6742333_23.html
# Subscribe
# Thomas Piketty
# Column
# No image
# ------
# 'There is a world of difference between how the media portrays JK Rowling and her image among the public'
# No subhead
# https://www.lemonde.fr/en/opinion/article/2025/06/13/there-is-a-world-of-difference-between-how-the-media-portrays-jk-rowling-and-her-image-among-the-public_6742323_23.html
# Subscribe
# Michel Guerrin
# Column
# https://img.lemde.fr/2025/02/13/0/0/0/0/100/100/60/0/582cc7b_sirius-fs-upload-1-s35ik04v2mji-1739442860260-capture-da-a-cran-2025-02-13-113357.png

# %%
rows = []

for article in articles:
    row = {}
    row['title'] = article.find(class_='article__title').text
    try:
       row['subhead'] = article.find(class_='article__desc').text
    except:
        pass
    try:
        row['article_url'] = article.find('a')['href']
    except:
        pass
    try:
        row['premium'] = article.find(class_='sr-only').text
    except:
        pass
    try:
        row['byline'] = article.select_one('.article__byline, .article__author-name').text
    except:
        pass
    try:
        row['article_type'] = article.find(class_="article__type").text
    except:
       pass
    try:
        row['image_url'] = article.find('img').get('data-src').text
    except:
        pass
    rows.append(row)

# %%
import pandas as pd

df = pd.json_normalize(rows)
df.head()
# Out:
#                                                title  \
# 0   Iran warns of 'devastating response' to Israe...
# 1  In Greenland, Macron criticizes Trump's annexa...
# 2  Was the Trump phenomenon a historical accident...
# 3  France's first Slow Fashion Week champions a s...
# 4  Paris Saint-Germain thrash Atlético 4-0 in Clu...
#
#                                              subhead  \
# 0  'Leave the occupied territories because they w...
# 1                                                NaN
# 2                                                NaN
# 3  Designers and vintage enthusiasts gathered in ...
# 4  PSG largely dominated Atlético at the Rose Bow...
#
#                                          article_url           premium byline  \
# 0  https://www.lemonde.fr/en/international/articl...  Subscribers only    NaN
# 1  https://www.lemonde.fr/en/international/articl...               NaN    NaN
# 2  https://www.lemonde.fr/en/international/articl...  Subscribers only    NaN
# 3  https://www.lemonde.fr/en/environment/article/...  Subscribers only    NaN
# 4  https://www.lemonde.fr/en/sports/article/2025/...               NaN    NaN
#
#   article_type
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.to_csv("lemonde.csv", index=False)
